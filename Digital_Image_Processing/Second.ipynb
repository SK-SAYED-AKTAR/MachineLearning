# %%
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread("./images/np_random.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# img.shape
img[150:260, 150:260, :] = [255, 0, 0]

# %%
plt.imshow(img)

# %%
plt.imshow(img*[0, 0, 1])

# %%
img = cv2.imread("./images/eye.jpeg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(img)
img
# Out:
# array([[[ 2,  3,  8],
#         [ 2,  3,  8],
#         [ 2,  3,  8],
#         ...,
#         [ 2,  2, 12],
#         [ 7,  7, 15],
#         [11, 11, 19]],
#
#        [[ 2,  3,  8],
#         [ 2,  3,  8],
#         [ 2,  3,  8],
#         ...,
#         [ 2,  2, 12],
#         [ 6,  6, 14],
#         [10, 10, 18]],
#
#        [[ 2,  2, 10],
#         [ 2,  2, 10],
#         [ 2,  2, 10],
#         ...,
#         [ 2,  2, 12],
#         [ 6,  6, 14],
#         [10, 10, 18]],
#
#        ...,
#
#        [[ 1,  0, 10],
#         [ 1,  0, 10],
#         [ 1,  0, 10],
#         ...,
#         [ 2,  1,  7],
#         [ 6,  5, 11],
#         [10,  9, 15]],
#
#        [[ 1,  0,  8],
#         [ 1,  0,  8],
#         [ 1,  0,  8],
#         ...,
#         [ 2,  1,  7],
#         [ 6,  5, 11],
#         [10,  9, 15]],
#
#        [[ 1,  0,  8],
#         [ 1,  0,  8],
#         [ 1,  0,  8],
#         ...,
#         [ 2,  1,  7],
#         [ 6,  5, 11],
#         [10,  9, 15]]], dtype=uint8)

# %%
plt.imshow(img*[1, 1, 0])

# %%
a = img*[2., 1., 0.]
a
# Out:
# array([[[ 4.,  3.,  0.],
#         [ 4.,  3.,  0.],
#         [ 4.,  3.,  0.],
#         ...,
#         [ 4.,  2.,  0.],
#         [14.,  7.,  0.],
#         [22., 11.,  0.]],
#
#        [[ 4.,  3.,  0.],
#         [ 4.,  3.,  0.],
#         [ 4.,  3.,  0.],
#         ...,
#         [ 4.,  2.,  0.],
#         [12.,  6.,  0.],
#         [20., 10.,  0.]],
#
#        [[ 4.,  2.,  0.],
#         [ 4.,  2.,  0.],
#         [ 4.,  2.,  0.],
#         ...,
#         [ 4.,  2.,  0.],
#         [12.,  6.,  0.],
#         [20., 10.,  0.]],
#
#        ...,
#
#        [[ 2.,  0.,  0.],
#         [ 2.,  0.,  0.],
#         [ 2.,  0.,  0.],
#         ...,
#         [ 4.,  1.,  0.],
#         [12.,  5.,  0.],
#         [20.,  9.,  0.]],
#
#        [[ 2.,  0.,  0.],
#         [ 2.,  0.,  0.],
#         [ 2.,  0.,  0.],
#         ...,
#         [ 4.,  1.,  0.],
#         [12.,  5.,  0.],
#         [20.,  9.,  0.]],
#
#        [[ 2.,  0.,  0.],
#         [ 2.,  0.,  0.],
#         [ 2.,  0.,  0.],
#         ...,
#         [ 4.,  1.,  0.],
#         [12.,  5.,  0.],
#         [20.,  9.,  0.]]])

# %%
plt.imshow(img[20:100, 10:200])
